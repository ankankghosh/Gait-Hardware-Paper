# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Conv1D, GlobalAveragePooling1D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# =========================
# Configuration and constants
# =========================
ROOT_DIR = 'All_10person_Cycles'
MAX_SEQUENCE_LENGTH = 180
TRAIN_RATIO = 0.8
VALID_LABELS = ['back', 'front', 'normal', 'side']
FEATURE_COLUMNS = [
    'IMU101_v0', 'IMU101_v1', 
    'IMU103_v0', 'IMU103_v1', 
    'IMU104_v0', 'IMU104_v1', 'IMU301_v0', 'IMU301_v1', 
    'x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6',
    'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15'
]

# Model hyperparameters
UNITS = 64
DROPOUT_RATE = 0.3
EPOCHS = 25
BATCH_SIZE = 32

def load_and_split_data():
    """Load cycles, select features, pad/truncate, encode labels, and split."""
    X_data, y_labels, cycle_ids = [], [], []

    if not os.path.exists(ROOT_DIR):
        return None, None, None, None, 0, 0, None

    for root, dirs, files in os.walk(ROOT_DIR):
        if root.endswith('Abnormal'):
            for filename in files:
                if not filename.endswith('.csv'):
                    continue
                file_path = os.path.join(root, filename)

                # Parse label and cycle id from filename
                parts = filename.replace('.csv', '').split('__')
                if len(parts) != 2:
                    continue
                name_label_part, raw_id_part = parts
                label = name_label_part.split('_')[-1]
                if raw_id_part.count('_') > 1:
                    continue
                if raw_id_part.count('_') == 1 and not raw_id_part.startswith('cycle_'):
                    continue
                cycle_id_str = raw_id_part.split('_')[-1]

                if label not in VALID_LABELS or not cycle_id_str.isdigit():
                    continue

                try:
                    df = pd.read_csv(file_path)
                except Exception:
                    continue

                # Feature selection
                if any(col not in df.columns for col in FEATURE_COLUMNS):
                    continue
                df = df[FEATURE_COLUMNS]
                cycle_features = df.values
                if cycle_features.shape[0] == 0 or cycle_features.shape[1] == 0:
                    continue

                # Pad/truncate to fixed length
                if cycle_features.shape[0] < MAX_SEQUENCE_LENGTH:
                    pad_len = MAX_SEQUENCE_LENGTH - cycle_features.shape[0]
                    padded = np.pad(cycle_features, ((0, pad_len), (0, 0)), 'constant', constant_values=0)
                else:
                    padded = cycle_features[:MAX_SEQUENCE_LENGTH, :]

                X_data.append(padded)
                y_labels.append(label)
                cycle_ids.append(file_path)

    if not X_data:
        return None, None, None, None, 0, 0, None

    X_full = np.array(X_data)
    y_full = np.array(y_labels)
    ids_full = np.array(cycle_ids)

    # Encode labels
    le = LabelEncoder()
    y_int = le.fit_transform(y_full)
    y_encoded = to_categorical(y_int)
    class_names = le.classes_

    num_features = X_full.shape[2]
    num_classes = y_encoded.shape[1]

    # Train/test split by unique file paths
    unique_ids = np.unique(ids_full)
    train_ids, test_ids = train_test_split(unique_ids, train_size=TRAIN_RATIO, random_state=42, shuffle=True)
    train_idx = np.where(np.isin(ids_full, train_ids))[0]
    test_idx = np.where(np.isin(ids_full, test_ids))[0]

    X_train, X_test = X_full[train_idx], X_full[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    return X_train, X_test, y_train, y_test, num_features, num_classes, class_names

def build_model(model_type, sequence_length, num_features, num_classes):
    """Build and compile a model of the requested type: 'lstm', 'gru', or 'cnn'."""
    if model_type == 'lstm':
        model = Sequential([
            LSTM(UNITS, input_shape=(sequence_length, num_features), return_sequences=False, name='LSTM'),
            Dropout(DROPOUT_RATE),
            Dense(num_classes, activation='softmax')
        ])
    elif model_type == 'gru':
        model = Sequential([
            GRU(UNITS, input_shape=(sequence_length, num_features), return_sequences=False, name='GRU'),
            Dropout(DROPOUT_RATE),
            Dense(num_classes, activation='softmax')
        ])
    elif model_type == 'cnn':
        model = Sequential([
            # Convolution over time steps
            Conv1D(filters=64, kernel_size=5, activation='relu', input_shape=(sequence_length, num_features)),
            Dropout(DROPOUT_RATE),
            Conv1D(filters=64, kernel_size=5, activation='relu'),
            GlobalAveragePooling1D(),
            Dropout(DROPOUT_RATE),
            Dense(num_classes, activation='softmax')
        ])
    else:
        raise ValueError(f"Unknown model_type: {model_type}")

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def train_and_compare():
    """Train and evaluate multiple architectures on the same split."""
    X_train, X_test, y_train, y_test, num_features, num_classes, class_names = load_and_split_data()
    if X_train is None or X_train.shape[0] < 1:
        print("Insufficient data; training aborted.")
        return

    sequence_length = X_train.shape[1]
    model_types = ['lstm', 'gru', 'cnn']

    for mtype in model_types:
        print(f"\n=== Training {mtype.upper()} model ===")
        model = build_model(mtype, sequence_length, num_features, num_classes)

        callbacks = [
            EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
            ModelCheckpoint(f'best_{mtype}_IMU+Pressure.weights.h5', monitor='val_loss', save_best_only=True, save_weights_only=True, verbose=0)
        ]

        history = model.fit(
            X_train, y_train,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(X_test, y_test),
            callbacks=callbacks,
            verbose=1
        )

        # Load best weights and evaluate
        try:
            model.load_weights(f'best_{mtype}_IMU+Pressure.weights.h5')
        except Exception as e:
            print(f"Warning: Could not load best weights for {mtype}: {e}")

        loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
        print(f"{mtype.upper()} Test Loss: {loss:.4f} | Test Accuracy: {accuracy:.4f}")

        # Classification report
        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        y_true = np.argmax(y_test, axis=1)
        print(f"\n{mtype.upper()} Classification Report:")
        print(classification_report(y_true, y_pred, target_names=class_names, zero_division=0))

if __name__ == '__main__':
    tf.get_logger().setLevel('INFO')
    train_and_compare()
# Out:
# === Training LSTM model ===
# Epoch 1/25
# /apps/anaconda/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.3617 - loss: 1.2768 - val_accuracy: 0.6915 - val_loss: 0.6823
# Epoch 2/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6346 - loss: 0.7444 - val_accuracy: 0.7321 - val_loss: 0.5808
# Epoch 3/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6829 - loss: 0.6830 - val_accuracy: 0.7756 - val_loss: 0.5236
# Epoch 4/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8332 - loss: 0.4755 - val_accuracy: 0.8888 - val_loss: 0.3941
# Epoch 5/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8512 - loss: 0.4899 - val_accuracy: 0.8366 - val_loss: 0.5094
# Epoch 6/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8783 - loss: 0.4355 - val_accuracy: 0.8897 - val_loss: 0.4094
# Epoch 7/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9062 - loss: 0.3385 - val_accuracy: 0.9110 - val_loss: 0.3084
# Epoch 8/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9168 - loss: 0.3003 - val_accuracy: 0.9391 - val_loss: 0.2414
# Epoch 9/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9349 - loss: 0.2363 - val_accuracy: 0.9217 - val_loss: 0.2942
# Epoch 10/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9236 - loss: 0.2730 - val_accuracy: 0.9362 - val_loss: 0.2228
# Epoch 11/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9092 - loss: 0.2826 - val_accuracy: 0.9333 - val_loss: 0.2224
# Epoch 12/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9414 - loss: 0.2061 - val_accuracy: 0.9207 - val_loss: 0.2924
# Epoch 13/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9362 - loss: 0.2343 - val_accuracy: 0.9420 - val_loss: 0.2149
# Epoch 14/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9411 - loss: 0.2119 - val_accuracy: 0.9613 - val_loss: 0.1592
# Epoch 15/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8176 - loss: 0.6467 - val_accuracy: 0.9362 - val_loss: 0.2404
# Epoch 16/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9495 - loss: 0.2037 - val_accuracy: 0.9410 - val_loss: 0.2052
# Epoch 17/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9531 - loss: 0.1676 - val_accuracy: 0.9333 - val_loss: 0.2266
# Epoch 18/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9589 - loss: 0.1676 - val_accuracy: 0.8820 - val_loss: 0.4789
# Epoch 19/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9256 - loss: 0.2625 - val_accuracy: 0.9594 - val_loss: 0.1550
# Epoch 20/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9499 - loss: 0.1499 - val_accuracy: 0.9545 - val_loss: 0.1589
# Epoch 21/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9681 - loss: 0.1165 - val_accuracy: 0.9516 - val_loss: 0.1707
# Epoch 22/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9596 - loss: 0.1267 - val_accuracy: 0.9594 - val_loss: 0.1447
# Epoch 23/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9732 - loss: 0.0903 - val_accuracy: 0.9691 - val_loss: 0.1273
# Epoch 24/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9708 - loss: 0.1132 - val_accuracy: 0.9632 - val_loss: 0.1286
# Epoch 25/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9736 - loss: 0.0896 - val_accuracy: 0.9574 - val_loss: 0.1639
# Restoring model weights from the end of the best epoch: 23.
# LSTM Test Loss: 0.1273 | Test Accuracy: 0.9691
#
# LSTM Classification Report:
#               precision    recall  f1-score   support
#
#         back       0.96      0.98      0.97       271
#        front       0.96      1.00      0.98       255
#       normal       0.98      0.95      0.96       246
#         side       0.97      0.95      0.96       262
#
#     accuracy                           0.97      1034
#    macro avg       0.97      0.97      0.97      1034
# weighted avg       0.97      0.97      0.97      1034
#
#
# === Training GRU model ===
# Epoch 1/25
# /apps/anaconda/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.2502 - loss: 1.4048 - val_accuracy: 0.2621 - val_loss: 1.3611
# Epoch 2/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2845 - loss: 1.3530 - val_accuracy: 0.4913 - val_loss: 1.0510
# Epoch 3/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5161 - loss: 0.9962 - val_accuracy: 0.6547 - val_loss: 0.7967
# Epoch 4/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6273 - loss: 0.7565 - val_accuracy: 0.7176 - val_loss: 0.6239
# Epoch 5/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7048 - loss: 0.6040 - val_accuracy: 0.7321 - val_loss: 0.5781
# Epoch 6/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7332 - loss: 0.5481 - val_accuracy: 0.7795 - val_loss: 0.5223
# Epoch 7/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7510 - loss: 0.5154 - val_accuracy: 0.8433 - val_loss: 0.4518
# Epoch 8/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8609 - loss: 0.4096 - val_accuracy: 0.9197 - val_loss: 0.3069
# Epoch 9/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9074 - loss: 0.3431 - val_accuracy: 0.9072 - val_loss: 0.3419
# Epoch 10/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9216 - loss: 0.3098 - val_accuracy: 0.9284 - val_loss: 0.2544
# Epoch 11/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9159 - loss: 0.3252 - val_accuracy: 0.9497 - val_loss: 0.2377
# Epoch 12/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9283 - loss: 0.2673 - val_accuracy: 0.8868 - val_loss: 0.4252
# Epoch 13/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8810 - loss: 0.4182 - val_accuracy: 0.9304 - val_loss: 0.2710
# Epoch 14/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9236 - loss: 0.2725 - val_accuracy: 0.9304 - val_loss: 0.2425
# Epoch 15/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8745 - loss: 0.3421 - val_accuracy: 0.8240 - val_loss: 0.4389
# Epoch 16/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8244 - loss: 0.3823 - val_accuracy: 0.8994 - val_loss: 0.3156
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
# GRU Test Loss: 0.2377 | Test Accuracy: 0.9497
#
# GRU Classification Report:
#               precision    recall  f1-score   support
#
#         back       0.92      0.98      0.95       271
#        front       0.96      0.98      0.97       255
#       normal       0.97      0.90      0.93       246
#         side       0.96      0.94      0.95       262
#
#     accuracy                           0.95      1034
#    macro avg       0.95      0.95      0.95      1034
# weighted avg       0.95      0.95      0.95      1034
#
#
# === Training CNN model ===
# Epoch 1/25
# /apps/anaconda/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.5910 - loss: 3.0399 - val_accuracy: 0.9120 - val_loss: 0.2507
# Epoch 2/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9065 - loss: 0.2685 - val_accuracy: 0.9584 - val_loss: 0.1568
# Epoch 3/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9284 - loss: 0.2020 - val_accuracy: 0.9691 - val_loss: 0.1235
# Epoch 4/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9588 - loss: 0.1436 - val_accuracy: 0.9700 - val_loss: 0.1204
# Epoch 5/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9697 - loss: 0.1027 - val_accuracy: 0.9787 - val_loss: 0.0847
# Epoch 6/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9638 - loss: 0.1062 - val_accuracy: 0.9758 - val_loss: 0.0789
# Epoch 7/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9700 - loss: 0.0894 - val_accuracy: 0.9816 - val_loss: 0.0955
# Epoch 8/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9685 - loss: 0.0980 - val_accuracy: 0.9932 - val_loss: 0.0470
# Epoch 9/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9752 - loss: 0.0736 - val_accuracy: 0.9894 - val_loss: 0.0557
# Epoch 10/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9769 - loss: 0.0730 - val_accuracy: 0.9913 - val_loss: 0.0434
# Epoch 11/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9793 - loss: 0.0556 - val_accuracy: 0.9913 - val_loss: 0.0585
# Epoch 12/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9804 - loss: 0.0560 - val_accuracy: 0.9826 - val_loss: 0.0594
# Epoch 13/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9809 - loss: 0.0694 - val_accuracy: 0.9942 - val_loss: 0.0358
# Epoch 14/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9885 - loss: 0.0393 - val_accuracy: 0.9913 - val_loss: 0.0394
# Epoch 15/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9842 - loss: 0.0486 - val_accuracy: 0.9884 - val_loss: 0.0471
# Epoch 16/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9861 - loss: 0.0468 - val_accuracy: 0.9884 - val_loss: 0.0471
# Epoch 17/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9818 - loss: 0.0496 - val_accuracy: 0.9768 - val_loss: 0.0785
# Epoch 18/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9889 - loss: 0.0411 - val_accuracy: 0.9952 - val_loss: 0.0319
# Epoch 19/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9883 - loss: 0.0321 - val_accuracy: 0.9932 - val_loss: 0.0327
# Epoch 20/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0347 - val_accuracy: 0.9855 - val_loss: 0.0635
# Epoch 21/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9832 - loss: 0.0508 - val_accuracy: 0.9874 - val_loss: 0.0675
# Epoch 22/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9853 - loss: 0.0376 - val_accuracy: 0.9942 - val_loss: 0.0308
# Epoch 23/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9923 - loss: 0.0282 - val_accuracy: 0.9855 - val_loss: 0.0490
# Epoch 24/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9937 - loss: 0.0253 - val_accuracy: 0.9913 - val_loss: 0.0395
# Epoch 25/25
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9901 - loss: 0.0299 - val_accuracy: 0.9884 - val_loss: 0.0511
# Restoring model weights from the end of the best epoch: 22.
# CNN Test Loss: 0.0308 | Test Accuracy: 0.9942
#
# CNN Classification Report:
#               precision    recall  f1-score   support
#
#         back       0.99      0.99      0.99       271
#        front       1.00      1.00      1.00       255
#       normal       1.00      1.00      1.00       246
#         side       0.99      0.99      0.99       262
#
#     accuracy                           0.99      1034
#    macro avg       0.99      0.99      0.99      1034
# weighted avg       0.99      0.99      0.99      1034
